# %%
def number_email_checker(username):
    list_username = list(username)
    n = 0
    for i in list_username:
        if i.isdigit() == True:
            n += 1
        elif i == "-":
            n += 1
        elif i == "_":
            n += 1
    if n == len(list_username):
        return 1
    else:
        return 0
# 此函式用在username沒有英文字母的判斷
# 注意這個username必須是字串的型態

# email_checker 1是Valid，0是Invalid
def email_checker(username, websitename, extension, country_code = "no"):
    if username.islower() == True:
        if (("-" in username) == True) & (("_" in username) == True):
            if websitename.isalnum() == True:
                if websitename.islower() == True:
                    if (len(extension) > 3) == True:
                        return 0
                    else:
                        if (len(country_code) > 2) == True:
                            return 0
                        if (len(country_code) == 1) == True:
                            return 0
                        else:
                            return 1
                elif websitename.isdigit() == True:
                    if (len(extension) > 3) == True:
                        return 0
                    else:
                        if (len(country_code) > 2) == True:
                            return 0
                        if (len(country_code) == 1) == True:
                            return 0
                        else:
                            return 1
                else:
                    return 0
            else:
                return 0
        elif ("-" in username) == True:
            if websitename.isalnum() == True:
                if websitename.islower() == True:
                    if (len(extension) > 3) == True:
                        return 0
                    else:
                        if (len(country_code) > 2) == True:
                            return 0
                        if (len(country_code) == 1) == True:
                            return 0
                        else:
                            return 1
                elif websitename.isdigit() == True:
                    if (len(extension) > 3) == True:
                        return 0
                    else:
                        if (len(country_code) > 2) == True:
                            return 0
                        if (len(country_code) == 1) == True:
                            return 0
                        else:
                            return 1
                else:
                    return 0
            else:
                return 0
        elif ("_" in username) == True:
            if websitename.isalnum() == True:
                if websitename.islower() == True:
                    if (len(extension) > 3) == True:
                        return 0
                    else:
                        if (len(country_code) > 2) == True:
                            return 0
                        if (len(country_code) == 1) == True:
                            return 0
                        else:
                            return 1
                elif websitename.isdigit() == True:
                    if (len(extension) > 3) == True:
                        return 0
                    else:
                        if (len(country_code) > 2) == True:
                            return 0
                        if (len(country_code) == 1) == True:
                            return 0
                        else:
                            return 1
                else:
                    return 0
            else:
                return 0
        elif username.isalnum() == True:
            if websitename.isalnum() == True:
                if websitename.islower() == True:
                    if (len(extension) > 3) == True:
                        return 0
                    else:
                        if (len(country_code) > 2) == True:
                            return 0
                        if (len(country_code) == 1) == True:
                            return 0
                        else:
                            return 1
                elif websitename.isdigit() == True:
                    if (len(extension) > 3) == True:
                        return 0
                    else:
                        if (len(country_code) > 2) == True:
                            return 0
                        if (len(country_code) == 1) == True:
                            return 0
                        else:
                            return 1
                else:
                    return 0
            else:
                return 0
#      此行確保無符號狀態
        else:
            return 0
#      這邊是其他符號不有效
#      下面是沒有英文字母的email的狀況
    elif number_email_checker(username) == 1:
        if websitename.isalnum() == True:
            if websitename.islower() == True:
                if (len(extension) > 3) == True:
                    return 0
                else:
                    if (len(country_code) > 2) == True:
                        return 0
                    if (len(country_code) == 1) == True:
                        return 0
                    else:
                        return 1
            elif websitename.isdigit() == True:
                    if (len(extension) > 3) == True:
                        return 0
                    else:
                        if (len(country_code) > 2) == True:
                            return 0
                        if (len(country_code) == 1) == True:
                            return 0
                        else:
                            return 1
            else:
                return 0
        else:
            return 0
    else:
        return 0
# 其他就是無效的email

# %%
email_number = int(input()) #要檢查的email數量
for i in range(email_number):
    email0 = input() #email樣式
    if (email0.count("@") != 1) == True:
        print("Invalid")
    elif (email0.count(".") > 2) == True:
        print("Invalid")
    else:
        email = email0.split("@")
        username = email[0]
        websitename = email[1].split(".")[0]
        extension = email[1].split(".")[1]
        if extension == "":
            print("Invalid")
        elif extension.isalnum() == False:
            print("Invalid")
        else:
            if len(email[1].split(".")) == 3:
                country_code = email[1].split(".")[2]
                if email_checker(username, websitename, extension, country_code) == 1:
                    print("Valid")
                else:
                    print("Invalid")
            elif len(email[1].split(".")) == 2:
                if email_checker(username, websitename, extension) == 1:
                    print("Valid")
                else:
                    print("Invalid")
            else:
                print("Invalid")
# Out:
# 3
# 105302037@nccu.edu.tw
# Valid
# 105302037@@jfkodjs.dfdss.tw
# Invalid
# ASasdsd_@google.com
# Invalid
