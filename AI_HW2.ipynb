# %%
#Wilcoxon Signed Ranks Test臨界值之查表建構
def Wilcoxon_Signed_Ranks_Test_Table(tail, alpha, n):
    if tail == "one":
        if alpha == 0.05:
            if n == 5:
                return "critical value is 0"
            elif n == 6:
                return "critical value is 2"
            elif n == 7:
                return "critical value is 3"
            elif n == 8:
                return "critical value is 5"
            elif n == 9:
                return "critical value is 8"
            elif n == 10:
                return "critical value is 10"
            elif n == 11:
                return "critical value is 13"
            elif n == 12:
                return "critical value is 17"
            elif n == 13:
                return "critical value is 21"
            elif n == 14:
                return "critical value is 25"
            elif n == 15:
                return "critical value is 30"
            elif n == 16:
                return "critical value is 35"
            elif n == 17:
                return "critical value is 41"
            elif n == 18:
                return "critical value is 47"
            elif n == 19:
                return "critical value is 53"
            elif n == 20:
                return "critical value is 60"
            elif n == 21:
                return "critical value is 67"
            elif n == 22:
                return "critical value is 75"
            elif n == 23:
                return "critical value is 83"
            elif n == 24:
                return "critical value is 91"
            elif n == 25:
                return "critical value is 100"
            elif n == 26:
                return "critical value is 110"
            elif n == 27:
                return "critical value is 119"
            elif n == 28:
                return "critical value is 130"
            elif n == 29:
                return "critical value is 140"
            elif n == 30:
                return "critical value is 151"
        elif alpha == 0.01:
            if n == 7:
                return "critical value is 0"
            elif n == 8:
                return "critical value is 1"
            elif n == 9:
                return "critical value is 3"
            elif n == 10:
                return "critical value is 5"
            elif n == 11:
                return "critical value is 7"
            elif n == 12:
                return "critical value is 9"
            elif n == 13:
                return "critical value is 12"
            elif n == 14:
                return "critical value is 15"
            elif n == 15:
                return "critical value is 19"
            elif n == 16:
                return "critical value is 23"
            elif n == 17:
                return "critical value is 27"
            elif n == 18:
                return "critical value is 32"
            elif n == 19:
                return "critical value is 37"
            elif n == 20:
                return "critical value is 43"
            elif n == 21:
                return "critical value is 49"
            elif n == 22:
                return "critical value is 55"
            elif n == 23:
                return "critical value is 62"
            elif n == 24:
                return "critical value is 69"
            elif n == 25:
                return "critical value is 76"
            elif n == 26:
                return "critical value is 84"
            elif n == 27:
                return "critical value is 92"
            elif n == 28:
                return "critical value is 101"
            elif n == 29:
                return "critical value is 110"
            elif n == 30:
                return "critical value is 120"
        else:
            return "not defined"
    elif tail == "two":
        if alpha == 0.05:
            if n == 6:
                return "critical value is 0"
            elif n == 7:
                return "critical value is 2"
            elif n == 8:
                return "critical value is 3"
            elif n == 9:
                return "critical value is 5"
            elif n == 10:
                return "critical value is 8"
            elif n == 11:
                return "critical value is 10"
            elif n == 12:
                return "critical value is 13"
            elif n == 13:
                return "critical value is 17"
            elif n == 14:
                return "critical value is 21"
            elif n == 15:
                return "critical value is 25"
            elif n == 16:
                return "critical value is 29"
            elif n == 17:
                return "critical value is 34"
            elif n == 18:
                return "critical value is 40"
            elif n == 19:
                return "critical value is 46"
            elif n == 20:
                return "critical value is 52"
            elif n == 21:
                return "critical value is 58"
            elif n == 22:
                return "critical value is 65"
            elif n == 23:
                return "critical value is 73"
            elif n == 24:
                return "critical value is 81"
            elif n == 25:
                return "critical value is 89"
            elif n == 26:
                return "critical value is 98"
            elif n == 27:
                return "critical value is 107"
            elif n == 28:
                return "critical value is 116"
            elif n == 29:
                return "critical value is 126"
            elif n == 30:
                return "critical value is 137"
        elif alpha == 0.01:
            if n == 8:
                return "critical value is 0"
            elif n == 9:
                return "critical value is 1"
            elif n == 10:
                return "critical value is 3"
            elif n == 11:
                return "critical value is 5"
            elif n == 12:
                return "critical value is 7"
            elif n == 13:
                return "critical value is 9"
            elif n == 14:
                return "critical value is 12"
            elif n == 15:
                return "critical value is 15"
            elif n == 16:
                return "critical value is 19"
            elif n == 17:
                return "critical value is 23"
            elif n == 18:
                return "critical value is 27"
            elif n == 19:
                return "critical value is 32"
            elif n == 20:
                return "critical value is 37"
            elif n == 21:
                return "critical value is 42"
            elif n == 22:
                return "critical value is 48"
            elif n == 23:
                return "critical value is 54"
            elif n == 24:
                return "critical value is 61"
            elif n == 25:
                return "critical value is 68"
            elif n == 26:
                return "critical value is 75"
            elif n == 27:
                return "critical value is 83"
            elif n == 28:
                return "critical value is 91"
            elif n == 29:
                return "critical value is 100"
            elif n == 30:
                return "critical value is 109"
        else:
            return "not defined"
    else:
        return "not defined"

# %%
#查表：單尾檢定 + 型一錯誤0.05 + 樣本數17
Wilcoxon_Signed_Ranks_Test_Table("one", 0.05, 17)
# Out:
# 'critical value is 41'

# %%
#查表：雙尾檢定 + 型一錯誤0.01 + 樣本數28
Wilcoxon_Signed_Ranks_Test_Table("two", 0.01, 28)
# Out:
# 'critical value is 91'
